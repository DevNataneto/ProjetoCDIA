# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
hapiness_df = pd.read_csv('https://raw.githubusercontent.com/DevNataneto/ProjetoCDIA/main/dataset/HappinessAlcoholConsumption.csv')
suicide_df = pd.read_csv('https://raw.githubusercontent.com/DevNataneto/ProjetoCDIA/main/dataset/SuicideRatesOverview1985To2016.csv')

# %% [markdown]
# # Analises Exploratorias

# %% [markdown]
# ## Analises do Data Set: 'Suicide Rates Overview'

# %%
suicide_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %% [markdown]
# Ao tentar obsevar os boxplots do numero de suicidos por ano, tornou-se ilegivel o gráfico, devido a grande quantidade de informação e disperção dos valores

# %%
sns.boxplot(x = suicide_df['year'], y = suicide_df['suicides_no'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='suicides_no'>

# %% [markdown]
# usando o metodo de [np.log] conesguimos deixar o grafico mais legivel e com maior controle dos dados

# %%
sns.boxplot(x = suicide_df['year'], y = np.log10(suicide_df['suicides_no']))
# Out:
# /home/jonasfelipe/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot:xlabel='year', ylabel='suicides_no'>

# %% [markdown]
# Aqui realizamos um grafico de dispersão, para observar as discrepancias dos dados

# %%
sns.scatterplot(x = suicide_df['year'], y = suicide_df['suicides_no'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='suicides_no'>

# %% [markdown]
# Aqui vamos observar a frequencia no 'suicide_no' com um histograma

# %%
sns.histplot(x = suicide_df['suicides_no'], bins = 20)
# Out:
# <AxesSubplot:xlabel='suicides_no', ylabel='Count'>

# %% [markdown]
# Como os valores ficaram muito proximo, realizamos novamente o uso do metodo [np.log10] para conseguirmos observar as grandezas dos dados, não somente o quantitativo puro

# %%
sns.histplot(x = np.log10(suicide_df['suicides_no']), bins = 20)
# Out:
# /home/jonasfelipe/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot:xlabel='suicides_no', ylabel='Count'>

# %% [markdown]
# ## Analises do Data Set: 'Happiness Alcohol Consumption'

# %% [markdown]
# ### Boxplot:

# %% [markdown]
# HDI = Human Development Index (IDH Indice de Desenvolvimento Humano) </br>
# há grande concentração de países com HDI entre 600 e 900 (HDIs altos)

# %%
sns.boxplot(y = hapiness_df['HDI'])
# Out:
# <AxesSubplot:ylabel='HDI'>

# %%
hapiness_df.columns
# Out:
# Index(['Country', 'Region', 'Hemisphere', 'HappinessScore', 'HDI',
#        'GDP_PerCapita', 'Beer_PerCapita', 'Spirit_PerCapita',
#        'Wine_PerCapita'],
#       dtype='object')

# %%
sns.boxplot(y = hapiness_df['HappinessScore'])
# Out:
# <AxesSubplot:ylabel='HappinessScore'>

# %% [markdown]
# Aqui observamos a dispersão dos valores de 'HapinessScore' (pontuação de felicidade) e o IDH do país. Alem de os hemisferios do planeta no qual aquele valor foi retirado

# %%
sns.scatterplot(x = hapiness_df['HappinessScore'], y = hapiness_df['HDI'], hue = hapiness_df['Hemisphere'])
# Out:
# <AxesSubplot:xlabel='HappinessScore', ylabel='HDI'>
